# %% [markdown]
# `shift + enter`

# %% [markdown]
# # Title
# ## Title
# ### Title
# #### Title
# ##### Title

# %% [markdown]
# * list
#     * list
#     - list
#     + list
# + list
# - list

# %% [markdown]
# 1. Element
# 2. Element
#     1. Element 2.1
#     2. Element 2.2
# 3. Element 3

# %% [markdown]
# *italics*  _italics_

# %% [markdown]
# **bold**  __bold__

# %% [markdown]
# ```html
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Document</title>
# </head>
# <body>
#
# </body>
# </html>
# ```

# %% [markdown]
# ```js
# alert("This is HS");
# ```

# %% [markdown]
# ***

# %% [markdown]
# ```python
# print()
# ```

# %% [markdown]
# -----------------------------------------

# %% [markdown]
# this is [link](https://google.com 'random text on hover-over')

# %% [markdown]
# | Syntax      | Description | Test Text     |
# | :---        |    :----:   |          ---: |
# | Header      | Title       | Here's this   |
# | Paragraph   | Text        | And more      |

# %% [markdown]
# this is an image ![image did not load](https://cdn.mos.cms.futurecdn.net/DQyNHder4hmYdLZ4Wf5oS3-1200-80.jpg.webp 'image')

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('vvGTc3LJtVQ', 800, 500)

# %%
from IPython.display import display
IFrame('https://www.youtube.com/embed/d9MyW72ELq0', 800, 500)
# Out:
#         <iframe
#             width="800"
#             height="500"
#             src="https://www.youtube.com/embed/d9MyW72ELq0"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
