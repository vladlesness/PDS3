# %%
import matplotlib.pyplot as plt
from matplotlib_venn import venn3

# %%
venn3(subsets = (3, 7, 3, 8, 5, 2, 4), set_labels = ('Mathematics', 'Physics', 'Chemistry'))
plt.show()

# %%
result = 3 + 3 + 4 + 5 + 7 + 2 + 8
result
# Out:
# 32

# %%
venn3(subsets = (5, 2, 4, 0, 2, 1, 1), set_labels = ('Rainy', 'Windy', 'Cold'))
plt.show()

# %%
result = 30 - 5 - 4 - 2 - 1 - 1 - 2
result
# Out:
# 15
